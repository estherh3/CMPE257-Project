# %% [markdown]
# <a href="https://colab.research.google.com/github/estherh3/CMPE257-Project/blob/main/Shabab_Siddiq_CMPE_257_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Project Title: Exploring Anomaly Detection with the Numenta Anomaly Benchmark (NAB) Dataset
#
# **Team Information**:
#
# Shabab Siddiq | shabab.siddiq@sjsu.edu | SJSU ID: 009101001
#
# Jason Lee | young.lee@sjsu.edu | SJSU ID: 015293408
#
# Esther Hammon | esther.hammon@sjsu.edu  | SJSU ID: 017530032
#
# **Project Option**: 2 :
#
# ML Model Training

# %% [markdown]
# ![image.png](data:image/png;base64,...)
